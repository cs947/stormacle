# %%
# Packages for general use
import numpy as np
import pandas as pd

# For handling data
from sklearn import preprocessing
import rasterio as rio

# Modeling
from sklearn import linear_model
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Event-specific Matrices

# %%
all_events_feats = pd.read_csv("Data/data_for_model.csv")

# %%
all_events_feats.columns
# Out:
# Index([u'EVENT_TYPE', u'MAGNITUDE', u'TOR_LENGTH', u'TOR_WIDTH', u'DURATION',
#        u'CLOSEST_HOSPITAL_DIST', u'NUM_COUNTY_HOSPITALS',
#        u'NUM_STATE_HOSPITALS', u'EPISODE_LENGTH', u'EVENT_LENGTH', u'DEATHS',
#        u'FLOOD_CAUSE_Dam / Levee Break', u'FLOOD_CAUSE_Heavy Rain',
#        u'FLOOD_CAUSE_Heavy Rain / Burn Area',
#        u'FLOOD_CAUSE_Heavy Rain / Snow Melt',
#        u'FLOOD_CAUSE_Heavy Rain / Tropical System',
#        u'FLOOD_CAUSE_Planned Dam Release', u'LAND_COVER_CLASS_1.0',
#        u'LAND_COVER_CLASS_2.0', u'LAND_COVER_CLASS_3.0',
#        u'LAND_COVER_CLASS_5.0', u'LAND_COVER_CLASS_6.0',
#        u'LAND_COVER_CLASS_7.0', u'LAND_COVER_CLASS_8.0',
#        u'LAND_COVER_CLASS_9.0', u'LAND_COVER_CLASS_10.0',
#        u'LAND_COVER_CLASS_11.0', u'LAND_COVER_CLASS_12.0',
#        u'LAND_COVER_CLASS_13.0', u'LAND_COVER_CLASS_14.0',
#        u'LAND_COVER_CLASS_15.0', u'LAND_COVER_CLASS_17.0', u'TOR_F_SCALE_EF0',
#        u'TOR_F_SCALE_EF1', u'TOR_F_SCALE_EF2', u'TOR_F_SCALE_EF3',
#        u'TOR_F_SCALE_EF4', u'TOR_F_SCALE_EF5', u'TOR_F_SCALE_F1',
#        u'TOR_F_SCALE_F2', u'TOR_F_SCALE_F3', u'FATALITY_LOCATION_Ball Field',
#        u'FATALITY_LOCATION_Boating', u'FATALITY_LOCATION_Business',
#        u'FATALITY_LOCATION_Camping', u'FATALITY_LOCATION_Church',
#        u'FATALITY_LOCATION_Golfing',
#        u'FATALITY_LOCATION_Heavy Equipment/Construction',
#        u'FATALITY_LOCATION_In Water', u'FATALITY_LOCATION_Long Span Roof',
#        u'FATALITY_LOCATION_Mobile/Trailer Home',
#        u'FATALITY_LOCATION_Other/Unknown',
#        u'FATALITY_LOCATION_Outside/Open Areas',
#        u'FATALITY_LOCATION_Permanent Home',
#        u'FATALITY_LOCATION_Permanent Structure', u'FATALITY_LOCATION_School',
#        u'FATALITY_LOCATION_Telephone', u'FATALITY_LOCATION_Under Tree',
#        u'FATALITY_LOCATION_Vehicle/Towed Trailer'],
#       dtype='object')

# %%
#Standardize non-binary columns
mlb = preprocessing.StandardScaler()
feature_column_names = ['MAGNITUDE', 'TOR_LENGTH', 'TOR_WIDTH', 'DURATION',
       'CLOSEST_HOSPITAL_DIST', 'NUM_COUNTY_HOSPITALS',
       'NUM_STATE_HOSPITALS', 'EPISODE_LENGTH', 'EVENT_LENGTH',]
feature_column = all_events_feats[feature_column_names]

#mask = feature_column.notnull() #Save location non-missing values, allows us to restore original indices after filtering na's

feature_matrix = mlb.fit_transform(all_events_feats[feature_column_names]) #Drop missing values and encode

#df = pd.DataFrame(feature_matrix, index=all_events_feats.index[mask], columns=feature_column_name+"_"+mlb.classes_) \
#    .reindex(all_events_feats.index, fill_value=0)  #restore original matrix with missing values - encoded as all 0's
    
#all_events_feats = all_events_feats.join(df).drop([feature_column_name], axis=1)
all_events_feats[feature_column_names] = feature_matrix

# %%
event_type = 'Wind'
wind_events = all_events_feats[all_events_feats['EVENT_TYPE']==event_type].pipe(
    pd.DataFrame.drop,
    labels=all_events_feats.filter(regex='EVENT|TOR|FLOOD|NARRATIVE'),
    axis=1, 
    inplace=False
)
wind_events.head(5)
# Out:
#     MAGNITUDE  DURATION  CLOSEST_HOSPITAL_DIST  NUM_COUNTY_HOSPITALS  \
# 0   -1.128760       0.0                    NaN             -0.194345
# 1   -0.059892       0.0                    NaN             -0.194345
# 2    0.340933       0.0                    NaN             -0.194345
# 9    0.073716       0.0                    NaN             -0.194345
# 10  -0.527522       0.0                    NaN              0.269730
#
#     NUM_STATE_HOSPITALS  EPISODE_LENGTH  DEATHS  LAND_COVER_CLASS_1.0  \
# 0              0.111398       -0.283799       1                     0
# 1              0.143012       -0.067288       1                     0
# 2              0.111398        0.026425       1                     0
# 9             -0.062482        0.307566       1                     0
# 10            -0.117808       -0.471226       1                     0
#
#     LAND_COVER_CLASS_2.0  LAND_COVER_CLASS_3.0  ...  \
# 0                      0                     0  ...
# 1                      0                     0  ...
# 2                      0                     0  ...
# 9                      0                     0  ...
# 10                     0                     0  ...
#
#     FATALITY_LOCATION_Long Span Roof  FATALITY_LOCATION_Mobile/Trailer Home  \
# 0                                  0                                      0
# 1                                  0                                      0
# 2                                  0                                      0
# 9                                  0                                      0
# 10                                 0                                      0
#
#     FATALITY_LOCATION_Other/Unknown  FATALITY_LOCATION_Outside/Open Areas  \
# 0                                 0                                     0
# 1                                 0                                     0
# 2                                 0                                     0
# 9                                 0                                     0
# 10                                0                                     0
#
#     FATALITY_LOCATION_Permanent Home  FATALITY_LOCATION_Permanent Structure  \
# 0                                  0                                      0
# 1                                  0                                      0
# 2                                  0                                      0
# 9                                  0                                      0
# 10                                 1                                      0
#
#     FATALITY_LOCATION_School  FATALITY_LOCATION_Telephone  \
# 0                          0                            0
# 1                          0                            0
# 2                          0                            0
# 9                          0                            0
# 10                         0                            0
#
#     FATALITY_LOCATION_Under Tree  FATALITY_LOCATION_Vehicle/Towed Trailer
# 0                              0                                        1
# 1                              0                                        1
# 2                              0                                        1
# 9                              0                                        1
# 10                             0                                        0
#
# [5 rows x 40 columns]

# %%
event_type = 'Tornado'
tor_events = all_events_feats[all_events_feats['EVENT_TYPE']==event_type].pipe(
    pd.DataFrame.drop,
    labels=all_events_feats.filter(regex='EVENT|FLOOD|NARRATIVE|MAGNITUDE'),
    axis=1, 
    inplace=False
)
tor_events.head(5)
# Out:
#     TOR_LENGTH  TOR_WIDTH  DURATION  CLOSEST_HOSPITAL_DIST  \
# 12   -1.329936   0.219557       0.0              -0.110321
# 16   -0.624952  -0.552269       0.0              -0.117146
# 17   -0.624952  -0.552269       0.0              -0.146693
# 38   -0.272460  -0.873863       0.0              -0.148474
# 39   -0.272460  -0.873863       0.0              -0.145246
#
#     NUM_COUNTY_HOSPITALS  NUM_STATE_HOSPITALS  EPISODE_LENGTH  DEATHS  \
# 12              0.037692            -0.094097       -0.471226       1
# 16              0.037692            -0.204748       -0.471226       2
# 17              0.037692            -0.204748       -0.471226       2
# 38              0.037692            -0.204748       -0.471226       1
# 39              0.037692            -0.204748       -0.471226       1
#
#     LAND_COVER_CLASS_1.0  LAND_COVER_CLASS_2.0  ...  \
# 12                     0                     0  ...
# 16                     0                     0  ...
# 17                     0                     0  ...
# 38                     0                     0  ...
# 39                     0                     0  ...
#
#     FATALITY_LOCATION_Long Span Roof  FATALITY_LOCATION_Mobile/Trailer Home  \
# 12                                 0                                      0
# 16                                 0                                      0
# 17                                 0                                      0
# 38                                 0                                      0
# 39                                 0                                      0
#
#     FATALITY_LOCATION_Other/Unknown  FATALITY_LOCATION_Outside/Open Areas  \
# 12                                0                                     0
# 16                                0                                     0
# 17                                0                                     0
# 38                                0                                     0
# 39                                0                                     0
#
#     FATALITY_LOCATION_Permanent Home  FATALITY_LOCATION_Permanent Structure  \
# 12                                 1                                      0
# 16                                 0                                      0
# 17                                 0                                      0
# 38                                 1                                      0
# 39                                 1                                      0
#
#     FATALITY_LOCATION_School  FATALITY_LOCATION_Telephone  \
# 12                         0                            0
# 16                         0                            0
# 17                         0                            0
# 38                         0                            0
# 39                         0                            0
#
#     FATALITY_LOCATION_Under Tree  FATALITY_LOCATION_Vehicle/Towed Trailer
# 12                             0                                        0
# 16                             0                                        1
# 17                             0                                        1
# 38                             0                                        0
# 39                             0                                        0
#
# [5 rows x 50 columns]

# %%
event_type = 'Flood'
flood_events = all_events_feats[all_events_feats['EVENT_TYPE']==event_type].pipe(
    pd.DataFrame.drop,
    labels=all_events_feats.filter(regex='EVENT|TOR|MAGNITUDE|NARRATIVE'),
    axis=1, 
    inplace=False
)
flood_events.head(5)
# Out:
#     DURATION  CLOSEST_HOSPITAL_DIST  NUM_COUNTY_HOSPITALS  \
# 18       0.0              -0.170574              0.269730
# 19       0.0              -0.176608              0.037692
# 29       0.0              -0.136093              0.269730
# 30       0.0              -0.109655              2.358065
# 32       0.0              -0.181610              1.429916
#
#     NUM_STATE_HOSPITALS  EPISODE_LENGTH  DEATHS  \
# 18             0.601424       -0.248253       1
# 19             0.601424       -0.248253       1
# 29             3.193818        0.346344       1
# 30             3.193818        0.346344       1
# 32             3.193818        0.346344       1
#
#     FLOOD_CAUSE_Dam / Levee Break  FLOOD_CAUSE_Heavy Rain  \
# 18                              0                       0
# 19                              0                       0
# 29                              0                       0
# 30                              0                       0
# 32                              0                       0
#
#     FLOOD_CAUSE_Heavy Rain / Burn Area  FLOOD_CAUSE_Heavy Rain / Snow Melt  \
# 18                                   0                                   0
# 19                                   0                                   0
# 29                                   0                                   0
# 30                                   0                                   0
# 32                                   0                                   0
#
#     ...  FATALITY_LOCATION_Long Span Roof  \
# 18  ...                                 0
# 19  ...                                 0
# 29  ...                                 0
# 30  ...                                 0
# 32  ...                                 0
#
#     FATALITY_LOCATION_Mobile/Trailer Home  FATALITY_LOCATION_Other/Unknown  \
# 18                                      0                                0
# 19                                      0                                0
# 29                                      0                                0
# 30                                      0                                0
# 32                                      0                                0
#
#     FATALITY_LOCATION_Outside/Open Areas  FATALITY_LOCATION_Permanent Home  \
# 18                                     0                                 0
# 19                                     0                                 0
# 29                                     0                                 0
# 30                                     0                                 0
# 32                                     0                                 0
#
#     FATALITY_LOCATION_Permanent Structure  FATALITY_LOCATION_School  \
# 18                                      0                         0
# 19                                      0                         0
# 29                                      0                         0
# 30                                      0                         0
# 32                                      0                         0
#
#     FATALITY_LOCATION_Telephone  FATALITY_LOCATION_Under Tree  \
# 18                            0                             0
# 19                            0                             0
# 29                            0                             0
# 30                            0                             0
# 32                            0                             0
#
#     FATALITY_LOCATION_Vehicle/Towed Trailer
# 18                                        1
# 19                                        0
# 29                                        0
# 30                                        0
# 32                                        0
#
# [5 rows x 45 columns]

# %% [markdown]
# # Models
